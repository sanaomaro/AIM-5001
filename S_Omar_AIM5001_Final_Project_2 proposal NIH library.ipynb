# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaomaro/AIM-5001/blob/main/S_Omar_AIM5001_Final_Project_2%20proposal%20NIH%20library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

from bs4 import BeautifulSoup

# %%
r=requests.get("https://www.nih.gov/")

r.status_code
# Out:
# 200

# %% [markdown]
# **Introduction:**
#
# According to nih.gov "The National Institutes of Health (NIH), a part of the U.S. Department of Health and Human Services, is the nation’s medical research agency — making important discoveries that improve health and save lives."
# Each time a new article or research is published, a new information is created about either drugs, diseases or helath behaviours of people.
# In this project we are trying to get some information about what could be dangerous and repetitivly been researched or mentioned.

# %% [markdown]
# **Research questions:**
#
# 1. What is the most word associated with the words: danger/dangerous/fatal? – research it in the title: could be a name of drug, disease etc.
#     In this point, we are trying to investigate in general what could be repetitivly described as dangerous and been researched by health researchers, what worries them the most.
# 2. How many times they were repeated?
#     by including the number or appearance of these kewords, we could know of qhat takes the priority of attention, and what does not, this could shed light on hidden patterns and help assesing serious problems that do not attract enough attention.
# 3. To what type do they belong? Drugs/disease/else?
#     further, categorize these keywords accordingly by extracting these information as well.
# 4. What is the section that has the most words? What type? is it article video … ect?
#     Ctaegorizing them by section, help knowing was these information educational on the form of lessons, or was it a research information. By default, leassons and alike are not of use because the intention of this research is to focus on what is being researched recently not what is being taught.
# 5. Refine the research according to two sections – excluding 2020:
#     - two years the after covid
#     - two years before covid
#     It is suggested to divide it into two periods: before and after covid, this will help exclude the hype attention on covid because a pandamic will require all the focus and might work as an outlier in the data.
#     Also, we do not want to include very old data, so two years only to asses what is recently been bothering researchers as fatal or serious or dangerous in the health field.
#
#     As described under each propsed question, this will help "real world" by mainly drawing attention to the most researched as "fatal" to the least researched as fatal, in that the least could be important but it is not being researched enough, and this "importance aspect" could be decided by a specialized researcher not by this research.
#
#
# Hint: this research might need text/sentimental analysis.

# %% [markdown]
# **Data to be Used:**
#
#
# As asked by the project guideline, Proposing two types of data (csv, scraping):
# 1. The main source is scraping data from https://www.nih.gov/.:
#     This could be done by using beautiful soup for any data, or https://newspaper.readthedocs.io/en/latest/ library package which is used specifically for articles type data.
# 2. Unfortunatley, I did not find any datasets that contain only the most dangerous drugs or diseases up to now, but I am still searching.
# 3. An API provided by the NIH: https://www.ncbi.nlm.nih.gov/home/develop/api/, these API's are still being evaluated for their use in this research.

# %% [markdown]
# **Approach:**
#
# 1. Explain how you plan to manage the data you are collecting: e.g., will you be storing it within some sort of database, etc.?
#
# Data will be stored in a csv file, containing the words: dager, dangerous, fatal, serious along with several keywords with them such as: name of drug, disease or discription of behaviour if applicable. Then it will be imported to Postgres for further analysis using sql.
#
# Also, the titles for each of these keywords will be stored in seperate colum along with the url in a seprate colum as well, the date of these materials.
# The research will be in the titles only not in the bodies of HTML pages, I beleive that a serious stuff will be mentioned in the title first as serious.
#
# 2. Explain what types of statistical analysis you plan to utilize to help answer your research questions. Explain any graphics you plan to generate to help answer your research questions.
#
# **Descriptive Analysis:**
#
# Collecting data as explained in the previous point and refining it into columns in a csv file and preparing it for Exploratory analysis.
#
# **Exploratory Analysis:**
#
# This research looks as if it will have only categorical data primarly, which is the number of apperances of a word.
#
# Thus, strip plots or swarm plots will be used as a start: sns.catplot(data=tips, x="level of seriousness", y="Number of appearance").
#
# HINT: level of seriousness refers to: fatal - danger/dangerous - serious in sequence from the most serious to the least.
#
# Another graph will be for the period of time that a specific (disease has been researched): for example if xyz disease was researched between March 2018 until Dec 2019, it will be graphed with the intensity of its researched against other diseases.. and so on.
#
# A boxplot will be used as well, it helps looking at the concentration average of research quantity for these keywords.
#
# HINT: by keywords I mean any drug or disease was associated with the level of seriousness words.
#
# Finally, bar plot is very imprtant as it is easily interpreted and understood with accurate representation for the number of apperances.
#
# **Inferential Analysis:**
#
# Drawing conclusions and meanings from the previous explained graphs and interpreting the relationships between data.
#
# **Finally, Sentimental Analysis:**
#
# It might be needed to further analys the text scraped from the website, and extract more features in depth from any articles or research desired.

# %% [markdown]
# STEPS: The same logical steps will be followed in this research, As in this image
#
# ![New Bitmap Image.bmp](data:image/bmp;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In the above image an attempt to inspect exactly the place of our data, the steps suggested to reach it is:
# 1. first: search in the website for danger or any other word of our four keywords.
# 2. then inspect the research result header which can be found at this tag sequence:
#    body --- div main-content --- div with id='search' --- h2 --- div with id='results' ---  div class="content-block-item content-block-item-header" --- h3 ---
#
#
# LASTLY:
# div class="content-block-item result" id="result-1"
# h4 class="title" a data-click="{&quot;position&quot;:1,&quot;module_code&quot;:&quot;BWEB&quot;}" href="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7878014/"><strong
# The Danger Assessment </strong - PMC - strong
# National Center for Biotechnology Information</strong </a
# /h4
# div class="url" www.ncbi.nlm.nih.gov/pmc/articles/PMC7878014/</div
# span class="description"
# strong The Danger Assessment</strong
#  (DA) is an instrument designed to assess the likelihood of lethality or near lethality occurring in a case of intimate partner ...
# /span
# div
#
# HINT: WE HAD TO REMOVE THE CLOSING TAG < TO MAKE IT LOOK AS TEXT
#
# HERE WE FIND OUR DATA:
# - The title in span tag of class description
# - The website href
# - Under the h4 class title

# %% [markdown]
# **A new feature:**
#
# It seems very interesting if there is a method that can catogorize the words being searched and extracted in this project into levels of intensity or what is called polarity. Furtunately, this can be done by the use of the TextBlob library.
#
# According to an answer from stackoverflow:
#
# "TextBlob internally uses NaiveBayes classifer for sentiment analysis, the naivebayes classifier used in turn is the one provided by NLTK. ... Get the positive and negative words from a Textblob based on its polarity in Python (Sentimental analysis) 0. Highest Polarity Score (Sentiment Analysis) using the TextBlob library" (stackoverflow, 2017)
#
# A probability distribution can be drawen as a result from Textblobs sentiment analyzer.
#
#
# ------------------------------------------------------------------------------
# According to nltk official documentation, the Naiive Bayes way of working is as the follwoing:
#
#
# NLTK is "A classifier based on the Naive Bayes algorithm.  In order to find the
# probability for a label, this algorithm first uses the Bayes rule to
# express P(label|features) in terms of P(label) and P(features|label):
#
# | P(label|features) =P(label) * P(features|label)/ P(features)
#
# The algorithm then makes the 'naive' assumption that all features are
# independent, given the label:
#
# | P(label|features) = P(label) * P(f1|label) * ... * P(fn|label)/P(features)
#
# Rather than computing P(features) explicitly, the algorithm just
# calculates the numerator for each label, and normalizes them so they
# sum to one:
#
# | P(label|features) =
# |                    P(label) * P(f1|label) * ... * P(fn|label)/
# |                    SUM[l]( P(l) * P(f1|l) * ... * P(fn|l))"
# (NLTK , 2022)
#
# NLTK and TextBolbs are part of NLP natural language processing in python, it can enhance analysing words in this project.

# %% [markdown]
# ***For the time being I still could not do a good scarping to provide premiraly results, but it is still working on it.***

# %% [markdown]
# References:
#
# 1. (2017, Jun 4). Polarity calculation in sentiment analysis using TextBlob. Stack Overflow. Retrieved November 4, 2022, from https://stackoverflow.com/questions/43871019/polarity-calculation-in-sentiment-analysis-using-textblob
#
# 2. Source code for nltk.classify.naivebayes. NLTK Documentation. (2022, March 25). Retrieved November 4, 2022, from https://www.nltk.org/_modules/nltk/classify/naivebayes.html
